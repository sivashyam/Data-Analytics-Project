# %% [markdown]
# ## HR Attrition Prediction
# Full notebook: EDA, preprocessing, model training (Logistic Regression & RandomForest), evaluation, and export.
#
# Generated dataset contains 12,000 rows.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder, StandardScaler
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix,roc_auc_score, roc_curve

# %%
df = pd.read_csv("HR_Employee_Data.csv")
df.head()
# Out:
#    EmployeeID  Age  Gender  Department            JobRole  Education  \
# 0       10001   58    Male     Finance  Financial Analyst          3
# 1       10002   48    Male       Sales    Sales Executive          3
# 2       10003   34  Female  Operations  Logistics Manager          2
# 3       10004   27  Female  Operations  Logistics Manager          3
# 4       10005   40    Male         R&D     Lab Technician          2
#
#      EducationField MaritalStatus  MonthlyIncome  DistanceFromHome  \
# 0     Life Sciences        Single           2712                26
# 1     Life Sciences        Single           6563                22
# 2     Life Sciences        Single           4407                46
# 3     Life Sciences        Single           5444                40
# 4  Technical Degree        Single           7624                18
#
#    YearsAtCompany  TrainingHours  LastPromotionYears  PerformanceRating  \
# 0               4              9                   9                  5
# 1               6            115                  10                  3
# 2               2             92                   0                  3
# 3               1             46                   6                  2
# 4               3            166                   0                  4
#
#    WorkLifeBalance OverTime Attrition
# 0                3      Yes       Yes
# 1                3       No        No
# 2                3       No       Yes
# 3                3       No        No
# 4                3       No        No

# %%
df.head
# Out:
# <bound method NDFrame.head of        EmployeeID  Age  Gender  Department             JobRole  Education  \
# 0           10001   58    Male     Finance   Financial Analyst          3
# 1           10002   48    Male       Sales     Sales Executive          3
# 2           10003   34  Female  Operations   Logistics Manager          2
# 3           10004   27  Female  Operations   Logistics Manager          3
# 4           10005   40    Male         R&D      Lab Technician          2
# ...           ...  ...     ...         ...                 ...        ...
# 11995       21996   58    Male         R&D  Research Scientist          4
# 11996       21997   40    Male       Sales       Sales Manager          3
# 11997       21998   49    Male         R&D  Research Scientist          4
# 11998       21999   32  Female       Sales     Sales Executive          4
# 11999       22000   56  Female          HR        HR Executive          3
#
#          EducationField MaritalStatus  MonthlyIncome  DistanceFromHome  \
# 0         Life Sciences        Single           2712                26
# 1         Life Sciences        Single           6563                22
# 2         Life Sciences        Single           4407                46
# 3         Life Sciences        Single           5444                40
# 4      Technical Degree        Single           7624                18
# ...                 ...           ...            ...               ...
# 11995     Life Sciences       Married           7149                30
# 11996             Other        Single           7434                 1
# 11997  Technical Degree        Single           4166                47
# 11998             Other       Married           9247                39
# 11999           Medical       Married          13007                40
#
#        YearsAtCompany  TrainingHours  LastPromotionYears  PerformanceRating  \
# 0                   4              9                   9                  5
# 1                   6            115                  10                  3
# 2                   2             92                   0                  3
# 3                   1             46                   6                  2
# 4                   3            166                   0                  4
# ...               ...            ...                 ...                ...
# 11995               4             72                   7                  3
# 11996               4            138                   7                  3
# 11997               3             35                   4                  3
# 11998               3            198                   6                  4
# 11999               4             54                   1                  4
#
#        WorkLifeBalance OverTime Attrition
# 0                    3      Yes       Yes
# 1                    3       No        No
# 2                    3       No       Yes
# 3                    3       No        No
# 4                    3       No        No
# ...                ...      ...       ...
# 11995                2       No        No
# 11996                3       No        No
# 11997                3       No        No
# 11998                2       No        No
# 11999                3       No        No
#
# [12000 rows x 17 columns]>

# %%
df.describe()
# Out:
#         EmployeeID           Age     Education  MonthlyIncome  \
# count  12000.00000  12000.000000  12000.000000   12000.000000
# mean   16000.50000     39.521833      3.247667    6101.750333
# std     3464.24595     11.433675      0.994272    2846.529815
# min    10001.00000     20.000000      1.000000    1500.000000
# 25%    13000.75000     30.000000      3.000000    3977.750000
# 50%    16000.50000     40.000000      3.000000    6040.500000
# 75%    19000.25000     49.000000      4.000000    8046.000000
# max    22000.00000     59.000000      5.000000   17570.000000
#
#        DistanceFromHome  YearsAtCompany  TrainingHours  LastPromotionYears  \
# count      12000.000000    12000.000000   12000.000000        12000.000000
# mean          25.376417        2.974667      99.675583            5.002917
# std           14.425015        1.715742      57.869518            3.173181
# min            1.000000        0.000000       0.000000            0.000000
# 25%           13.000000        2.000000      49.000000            2.000000
# 50%           26.000000        3.000000      99.000000            5.000000
# 75%           38.000000        4.000000     150.000000            8.000000
# max           50.000000       14.000000     200.000000           10.000000
#
#        PerformanceRating  WorkLifeBalance
# count       12000.000000     12000.000000
# mean            3.300250         2.960583
# std             0.765495         0.739983
# min             1.000000         1.000000
# 25%             3.000000         3.000000
# 50%             3.000000         3.000000
# 75%             4.000000         3.000000
# max             5.000000         4.000000

# %%
df.isnull().sum()
# Out:
# EmployeeID            0
# Age                   0
# Gender                0
# Department            0
# JobRole               0
# Education             0
# EducationField        0
# MaritalStatus         0
# MonthlyIncome         0
# DistanceFromHome      0
# YearsAtCompany        0
# TrainingHours         0
# LastPromotionYears    0
# PerformanceRating     0
# WorkLifeBalance       0
# OverTime              0
# Attrition             0
# dtype: int64

# %%
df.isnull().any()
# Out:
# EmployeeID            False
# Age                   False
# Gender                False
# Department            False
# JobRole               False
# Education             False
# EducationField        False
# MaritalStatus         False
# MonthlyIncome         False
# DistanceFromHome      False
# YearsAtCompany        False
# TrainingHours         False
# LastPromotionYears    False
# PerformanceRating     False
# WorkLifeBalance       False
# OverTime              False
# Attrition             False
# dtype: bool

# %%
df.isnull()
# Out:
#        EmployeeID    Age  Gender  Department  JobRole  Education  \
# 0           False  False   False       False    False      False
# 1           False  False   False       False    False      False
# 2           False  False   False       False    False      False
# 3           False  False   False       False    False      False
# 4           False  False   False       False    False      False
# ...           ...    ...     ...         ...      ...        ...
# 11995       False  False   False       False    False      False
# 11996       False  False   False       False    False      False
# 11997       False  False   False       False    False      False
# 11998       False  False   False       False    False      False
# 11999       False  False   False       False    False      False
#
#        EducationField  MaritalStatus  MonthlyIncome  DistanceFromHome  \
# 0               False          False          False             False
# 1               False          False          False             False
# 2               False          False          False             False
# 3               False          False          False             False
# 4               False          False          False             False
# ...               ...            ...            ...               ...
# 11995           False          False          False             False
# 11996           False          False          False             False
# 11997           False          False          False             False
# 11998           False          False          False             False
# 11999           False          False          False             False
#
#        YearsAtCompany  TrainingHours  LastPromotionYears  PerformanceRating  \
# 0               False          False               False              False
# 1               False          False               False              False
# 2               False          False               False              False
# 3               False          False               False              False
# 4               False          False               False              False
# ...               ...            ...                 ...                ...
# 11995           False          False               False              False
# 11996           False          False               False              False
# 11997           False          False               False              False
# 11998           False          False               False              False
# 11999           False          False               False              False
#
#        WorkLifeBalance  OverTime  Attrition
# 0                False     False      False
# 1                False     False      False
# 2                False     False      False
# 3                False     False      False
# 4                False     False      False
# ...                ...       ...        ...
# 11995            False     False      False
# 11996            False     False      False
# 11997            False     False      False
# 11998            False     False      False
# 11999            False     False      False
#
# [12000 rows x 17 columns]

# %%
df.dtypes
# Out:
# EmployeeID             int64
# Age                    int64
# Gender                object
# Department            object
# JobRole               object
# Education              int64
# EducationField        object
# MaritalStatus         object
# MonthlyIncome          int64
# DistanceFromHome       int64
# YearsAtCompany         int64
# TrainingHours          int64
# LastPromotionYears     int64
# PerformanceRating      int64
# WorkLifeBalance        int64
# OverTime              object
# Attrition             object
# dtype: object

# %%
df.shape
# Out:
# (12000, 17)

# %%
df.columns
# Out:
# Index(['EmployeeID', 'Age', 'Gender', 'Department', 'JobRole', 'Education',
#        'EducationField', 'MaritalStatus', 'MonthlyIncome', 'DistanceFromHome',
#        'YearsAtCompany', 'TrainingHours', 'LastPromotionYears',
#        'PerformanceRating', 'WorkLifeBalance', 'OverTime', 'Attrition'],
#       dtype='object')

# %%
le = LabelEncoder()

for col in df.columns:
    if df[col].dtype == 'object':
        df[col] = le.fit_transform(df_clean[col])

# %%
# Encode target
le_target = LabelEncoder()
df['AttritionFlag'] = le_target.fit_transform(df['Attrition'])

# %%
x=df[['EmployeeID','Attrition','AttritionFlag']]
x
# Out:
#        EmployeeID  Attrition  AttritionFlag
# 0           10001          1              1
# 1           10002          0              0
# 2           10003          1              1
# 3           10004          0              0
# 4           10005          0              0
# ...           ...        ...            ...
# 11995       21996          0              0
# 11996       21997          0              0
# 11997       21998          0              0
# 11998       21999          0              0
# 11999       22000          0              0
#
# [12000 rows x 3 columns]

# %%
y= df[['AttritionFlag']]
y
# Out:
#        AttritionFlag
# 0                  1
# 1                  0
# 2                  1
# 3                  0
# 4                  0
# ...              ...
# 11995              0
# 11996              0
# 11997              0
# 11998              0
# 11999              0
#
# [12000 rows x 1 columns]

# %%
x_train,x_test,y_train,y_test= train_test_split(x,y,test_size=1,random_state=50)
print(x_train,x_test,y_train,y_test)
# Out:
#        EmployeeID  Attrition  AttritionFlag
# 2162        12163          0              0
# 6143        16144          0              0
# 2524        12525          0              0
# 9586        19587          0              0
# 1124        11125          0              0
# ...           ...        ...            ...
# 8324        18325          0              0
# 10206       20207          0              0
# 6253        16254          1              1
# 10123       20124          0              0
# 5600        15601          0              0
#
# [11999 rows x 3 columns]       EmployeeID  Attrition  AttritionFlag
# 5789       15790          0              0        AttritionFlag
# 2162               0
# 6143               0
# 2524               0
# 9586               0
# 1124               0
# ...              ...
# 8324               0
# 10206              0
# 6253               1
# 10123              0
# 5600               0
#
# [11999 rows x 1 columns]       AttritionFlag
# 5789              0

# %%
scaled=StandardScaler()
x_scaled=scaled.fit_transform(x)

# %%
print(x_train.shape)
print(x_test.shape)
print(y_train.shape)
print(y_test.shape)
# Out:
# (11999, 3)
# (1, 3)
# (11999, 1)
# (1, 1)

# %%
 #Logistic Regression
lr = LogisticRegression(max_iter=1000)
lr.fit(x_train, y_train)
# Out:
# C:\Users\sivas\AppData\Roaming\Python\Python313\site-packages\sklearn\utils\validation.py:1406: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# LogisticRegression(max_iter=1000)

# %%
y_pred_lr = lr.predict(x_test)
y_pred_lr
# Out:
# array([0])

# %%
print('Logistic Regression Accuracy:', accuracy_score(y_test, y_pred_lr))
# Out:
# Logistic Regression Accuracy: 1.0

# %%
print(classification_report(y_test, y_pred_lr))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00         1
#
#     accuracy                           1.00         1
#    macro avg       1.00      1.00      1.00         1
# weighted avg       1.00      1.00      1.00         1

# %%
# New hr attrition input
ne = np.array([[10001,1,1]])

# Predict
ps = lr.predict(ne)

# Print properly
print(f"Predicted atrriction: {ps[0].item():.2f}")
# Out:
# Predicted atrriction: 1.00
# C:\Users\sivas\AppData\Roaming\Python\Python313\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but LogisticRegression was fitted with feature names
#   warnings.warn(

# %%
# Random Forest
rf = RandomForestClassifier(n_estimators=100, random_state=42)
rf.fit(x_train, y_train)
y_pred_rf = rf.predict(x_test)
# Out:
# C:\Users\sivas\AppData\Roaming\Python\Python313\site-packages\sklearn\base.py:1365: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)

# %%
print('Random Forest Accuracy:', accuracy_score(y_test, y_pred_rf))
# Out:
# Random Forest Accuracy: 1.0

# %%
print(classification_report(y_test, y_pred_rf))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00         1
#
#     accuracy                           1.00         1
#    macro avg       1.00      1.00      1.00         1
# weighted avg       1.00      1.00      1.00         1

# %%
cnf=confusion_matrix(y_test, y_pred_rf)
cnf
# Out:
# C:\Users\sivas\AppData\Roaming\Python\Python313\site-packages\sklearn\metrics\_classification.py:534: UserWarning: A single label was found in 'y_true' and 'y_pred'. For the confusion matrix to have the correct shape, use the 'labels' parameter to pass all known labels.
#   warnings.warn(
# array([[1]])

# %%
# New HR attrition input
ne = np.array([[10001,1,1]])

# Predict (gives 0 or 1)
ps = rf.predict(ne)

# Decode prediction back to Yes/No
decoded = target_encoder.inverse_transform(ps)

print("Predicted Attrition:", decoded[0])
# Out:
# Predicted Attrition: 1
# C:\Users\sivas\AppData\Roaming\Python\Python313\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(

# %% [markdown]
# ## Recommendations
# Implement targeted retention programs for employees in Sales and those with low income.
# Focus on early-career employees (0–2 years) with mentoring and growth plans.
# Offer flexible work options for employees with long commute distances.
# Regularly monitor performance ratings and provide learning opportunities.
